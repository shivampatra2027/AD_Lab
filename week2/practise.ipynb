# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error,r2_score
import matplotlib.pyplot as plt

# %%
data=pd.read_csv("Student_Performance_Dataset.csv")

# %%
X=data[['Study_Hours_Per_Day','Attendance_Percentage']]
y=data['Final_Percentage']

# %%
X_train,X_test,y_train,y_test = train_test_split(
    X,y,test_size = 0.1,random_state=10
)

# %%
model=LinearRegression()
model.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred = model.predict(X_test)

# %%
mse = mean_squared_error(y_test,y_pred)
r2=r2_score(y_test,y_pred)

# %%
print("Mean sq error (MSE)",mse)
# Out:
# Mean sq error (MSE) 111.59742018935549

# %%
print("R2 score",r2)
# Out:
# R2 score -0.0008342273633656916

# %%
import numpy as np
plt.scatter(y_test, y_pred, color='blue')
plt.plot([y_test.min(), y_test.max()], [y_test.min(), y_test.max()], 'r--')
# Add regression line of predictions
z = np.polyfit(y_test, y_pred, 1)
p = np.poly1d(z)
plt.plot(y_test, p(y_test), "g-")
plt.xlabel("Actual Final Grade (G3)")
plt.ylabel("Predicted Final Grade (G3)")
plt.title("Actual vs Predicted Student Performance with Trend Line")
plt.show()
